# %% [markdown]
# # Weather Data Analysis 🌤️
#
# Interactive analysis of weather data from 5 major cities around the world.
#
# **Data Source**: Open-Meteo API
# **Cities**: Berlin, London, New York, Tokyo, Sydney
# **Time Period**: Last 7 days (hourly data)

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# Set plotting style
plt.style.use('default')
sns.set_palette("husl")
plt.rcParams['figure.figsize'] = (12, 6)

print("📦 Libraries loaded successfully!")
# Out:
# 📦 Libraries loaded successfully!

# %%
# Load weather data
weather_df = pd.read_csv('../data/clean_weather.csv')

# Convert timestamp to datetime
weather_df['timestamp'] = pd.to_datetime(weather_df['timestamp'])

print(f"📊 Dataset loaded: {len(weather_df):,} records")
print(f"🌍 Cities: {', '.join(weather_df['city'].unique())}")
print(f"📅 Date range: {weather_df['timestamp'].min().date()} to {weather_df['timestamp'].max().date()}")

# Display first few rows
weather_df.head()
# Out:
# 📊 Dataset loaded: 960 records
# 🌍 Cities: Berlin, London, New York, Tokyo, Sydney
# 📅 Date range: 2025-07-19 to 2025-07-26
#      city  country  latitude  longitude           timestamp  temperature_c  \
# 0  Berlin  Germany     52.52      13.41 2025-07-19 00:00:00           18.2
# 1  Berlin  Germany     52.52      13.41 2025-07-19 01:00:00           17.9
# 2  Berlin  Germany     52.52      13.41 2025-07-19 02:00:00           17.4
# 3  Berlin  Germany     52.52      13.41 2025-07-19 03:00:00           16.7
# 4  Berlin  Germany     52.52      13.41 2025-07-19 04:00:00           16.2
#
#    humidity_percent  wind_speed_kmh  precipitation_mm  \
# 0              86.0             2.4               0.0
# 1              86.0             2.1               0.0
# 2              88.0             2.2               0.0
# 3              89.0             3.0               0.0
# 4              91.0             1.4               0.0
#
# ...

# %%
# Temperature distribution by city
plt.figure(figsize=(12, 6))
weather_df.boxplot(column='temperature_c', by='city')
plt.title('🌡️ Temperature Distribution by City')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show();
